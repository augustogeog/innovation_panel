# %%
import pandas as pd
from pandas.api.types import CategoricalDtype
import numpy as np
pd.options.display.float_format = '{:,.2f}'.format
import os
from itertools import product
import app_rais.dicts_constants as dc
import app_rais.treat as treat

# %%
list_column_keep = dc.interest_columns_for_year(2018)

# %%
list_ufs=['AM', 'BA', 'CE', 'DF', 'ES', 'GO', 'MG','PA','PE','PR','RJ','RS','SC','SP']

# %%
# %%time
treat.pretreat_2018(list_ufs=list_ufs)
# Out:
# AM2018.txt saved.
# None
# BA2018.txt already exists.
# CE2018.txt already exists.
# DF2018.txt already exists.
# ES2018.txt already exists.
# GO2018.txt already exists.
# MG2018.txt already exists.
# PA2018.txt already exists.
# PE2018.txt already exists.
# PR2018.txt already exists.
# RJ2018.txt already exists.
# RS2018.txt already exists.
# SC2018.txt already exists.
# SP2018.txt already exists.
# Wall time: 1min

# %%
# %%time
treat.original_to_treated_loop(
    ufs=['AM']
    , years=[2018]
)
# Out:
# AM2018.zip saved.
# Wall time: 7.8 s

# %%
# %%time
treat.original_to_treated_loop(
    ufs=['AM', 'BA', 'CE', 'DF', 'ES', 'GO', 'MG','PA','PE','PR','RJ','RS','SC','SP']
    , years=[2018]
)
# Out:
# AM2018.zip saved.
# BA2018.zip saved.
# CE2018.zip saved.
# DF2018.zip saved.
# ES2018.zip saved.
# GO2018.zip saved.
# MG2018.zip saved.
# PA2018.zip saved.
# PE2018.zip saved.
# PR2018.zip saved.
# RJ2018.zip saved.
# RS2018.zip saved.
# SC2018.zip saved.
# SP2018.zip saved.
# Wall time: 8min 54s

# %%
# %%time
treat.load_save_rais_dataframe_loop(
    list_ufs=['AM', 'BA', 'CE', 'DF', 'ES', 'GO', 'MG','PA','PE','PR','RJ','RS','SC','SP']
    , list_years=[2018])
# Out:
# ufs_with_motropolises_2018 saved.
# Wall time: 1min 49s

# %%
df = pd.read_csv('app_rais/data/rais_original/2018/AM2018.txt', encoding='Latin-1', sep=';', decimal=',', dtype=dc.dic_dtype)

# %%
pd.read_pickle('app_rais/data/rais_treated/2018/AM2018.zip')
# Out:
#        CBO Ocupação 2002 CNAE 2.0 Classe CNAE 95 Classe Faixa Etária  \
# 0                 514320           56201          55247           06
# 1                 514225           77110          71102           07
# 2                 513610           56112          55212           03
# 3                 514325           10538          15431           03
# 4                 717020           81214          74705           05
# ...                  ...             ...            ...          ...
# 132238            234405           85317          80314           06
# 132239            231205           85317          80314           07
# 132240            234624           85317          80314           07
# 132241            234415           85317          80314           07
# 132242            223505           84116          75116           07
#
#        Faixa Remun Dezem (SM) Faixa Remun Média (SM) Escolaridade após 2005  \
# ...

# %%
df = pd.read_pickle('app_rais/data/rais_treated/2000/PR2000.zip')
