# %% [markdown]
# # COLLECTING AND TREATING RAIS DATA
#
#
# Aiming to analyse **scientific, technological and innovative ecosystems in Brazilian metropolises**, this notebook presents the process through which the Brazilian formal employment data from the **Annual List of Social Information, or RAIS** in Portuguese abbreviation, is collected and treated to create a database that carries meaningful attributes for the project in an agile format.
#
# RAIS data is available via its [microdata server](ftp://ftp.mtps.gov.br/pdet/microdados/RAIS/) and comprises several 7zip compressed files, organized by year and Federation Unities (states and Federal District), with about 30 columns and one row for each formal employment contract. With that structure, retrieving information often demands a lot of process power and RAM. As it is, it also do not ensure that the right kind of information can be achieved, unless the data is grouped according to well established concepts and criteria.
#
# Intending to work around this issues, Python packages, modules and functions are applied in the sessions ahead to collect and treat RAIS data. After the work flow applied in this notebook, the resulting data structure allows fast retrieving, adequate codification for exploratory analysis and comparative analysis, better performance for potential modeling operations and for public availability through web applications.

# %% [markdown]
# ## PREPARING THE NOTEBOOK

# %% [markdown]
# The virtual environment used in the project of data analysis has some packages that were installed and are available (as shown in the result of the code cell below). A Python package was developed for this project, called app_rais, which carries modules and their functions suited for operations with Rais data: download, transformation, cleaning, optimization and analysis.
#
# Therefore, this notebook was prepared with some Python packages and modules suited to the tasks related to collect and treat RAIS data. The imported packages can be seen in the second code cell ahead.

# %%
! conda list
# Out:
# # packages in environment at C:\Users\augus\Anaconda3\envs\innovation_panel:
# #
# # Name                    Version                   Build  Channel
# aiohttp                   3.6.2                    pypi_0    pypi
# astroid                   2.4.2                    pypi_0    pypi
# async-timeout             3.0.1                    pypi_0    pypi
# attrs                     19.3.0                     py_0
# backcall                  0.2.0                      py_0
# beautifulsoup4            4.9.1                    pypi_0    pypi
# blas                      1.0                         mkl
# bleach                    3.1.5                      py_0
# brotlipy                  0.7.0           py36he774522_1000
# bzip2                     1.0.8                he774522_0
# ca-certificates           2020.6.20            hecda079_0    conda-forge
# certifi                   2020.6.20        py36h9f0ad1d_0    conda-forge
# cffi                      1.14.0           py36h7a1dbc1_0
# cfitsio                   3.470                he774522_5
# chardet                   3.0.4                 py36_1003
# click                     7.1.2                      py_0
# click-plugins             1.1.1                      py_0
# cligj                     0.5.0                    py36_0
# colorama                  0.4.3                      py_0
# cryptography              2.9.2            py36h7a1dbc1_0
# curl                      7.67.0               h2a8f88b_0
# cycler                    0.10.0           py36h009560c_0
# decorator                 4.4.2                      py_0
# defusedxml                0.6.0                      py_0
# descartes                 1.1.0                      py_4
# entrypoints               0.3                      py36_0
# expat                     2.2.9                h33f27b4_2
# filelock                  3.0.12                   pypi_0    pypi
# fiona                     1.8.13.post1     py36hd760492_0
# freetype                  2.10.2               hd328e21_0
# freexl                    1.0.5                hfa6e2cd_0
# gdal                      3.0.2            py36hdf43c64_0
# geopandas                 0.8.1                      py_0
# geos                      3.8.0                h33f27b4_0
# geotiff                   1.5.1                h5770a2b_1
# google                    3.0.0                    pypi_0    pypi
# grpcio                    1.32.0                   pypi_0    pypi
# hdf4                      4.2.13               h712560f_2
# hdf5                      1.10.4               h7ebc959_0
# icc_rt                    2019.0.0             h0cc432a_1
# icu                       58.2                 ha925a31_3
# idna                      2.10                       py_0
# idna-ssl                  1.1.0                    pypi_0    pypi
# importlib-metadata        1.7.0                    py36_0
# importlib_metadata        1.7.0                         0
# intel-openmp              2020.1                      216
# ipykernel                 5.3.4            py36h5ca1d4c_0
# ipython                   7.16.1           py36h5ca1d4c_0
# ipython_genutils          0.2.0                    py36_0
# ipywidgets                7.5.1                      py_0
# isort                     5.5.4                    pypi_0    pypi
# jedi                      0.17.2                   py36_0
# jinja2                    2.11.2                     py_0
# jpeg                      9b                   hb83a4c4_2
# json5                     0.9.5                      py_0
# jsonschema                3.2.0                    py36_0
# jupyter                   1.0.0                    py36_7
# jupyter_client            6.1.6                      py_0
# jupyter_console           6.1.0                      py_0
# jupyter_contrib_core      0.3.3                      py_2    conda-forge
# jupyter_contrib_nbextensions 0.5.1                    py36_0    conda-forge
# jupyter_core              4.6.3                    py36_0
# jupyter_highlight_selected_word 0.2.0                 py36_1000    conda-forge
# jupyter_latex_envs        1.4.4                 py36_1000    conda-forge
# jupyter_nbextensions_configurator 0.4.1            py36h9f0ad1d_1    conda-forge
# jupyterlab                2.1.5                      py_0
# jupyterlab_server         1.2.0                      py_0
# kealib                    1.4.7                h07cbb95_6
# kiwisolver                1.2.0            py36h74a9793_0
# krb5                      1.16.4               hc04afaa_0
# lazy-object-proxy         1.4.3                    pypi_0    pypi
# libboost                  1.67.0               hd9e427e_4
# libcurl                   7.67.0               h2a8f88b_0
# libgdal                   3.0.2                h1155b67_0
# libiconv                  1.15                 h1df5818_7
# libkml                    1.3.0                he5f2a48_4
# libnetcdf                 4.6.1                h411e497_2
# libpng                    1.6.37               h2a8f88b_0
# libpq                     11.2                 h3235a2c_0
# libsodium                 1.0.18               h62dcd97_0
# libspatialindex           1.9.3                h33f27b4_0
# libspatialite             4.3.0a               h7ffb84d_0
# libssh2                   1.9.0                h7a1dbc1_1
# libtiff                   4.1.0                h56a325e_0
# libxml2                   2.9.10               h464c3ec_1
# libxslt                   1.1.33               h579f668_1    conda-forge
# lxml                      4.5.2            py36hd9844f4_0    conda-forge
# lz4-c                     1.8.1.2              h2fa13f4_0
# m2w64-expat               2.1.1                         2
# m2w64-gcc-libgfortran     5.3.0                         6
# m2w64-gcc-libs            5.3.0                         7
# m2w64-gcc-libs-core       5.3.0                         7
# m2w64-gettext             0.19.7                        2
# m2w64-gmp                 6.1.0                         2
# m2w64-libiconv            1.14                          6
# m2w64-libwinpthread-git   5.0.0.4634.697f757               2
# m2w64-xz                  5.2.2                         2
# markupsafe                1.1.1            py36he774522_0
# matplotlib                3.1.3                    py36_0
# matplotlib-base           3.1.3            py36h64f37c6_0
# mccabe                    0.6.1                    pypi_0    pypi
# mistune                   0.8.4            py36he774522_0
# mkl                       2020.1                      216
# mkl-service               2.3.0            py36hb782905_0
# mkl_fft                   1.1.0            py36h45dec08_0
# mkl_random                1.1.1            py36h47e9c7a_0
# modin                     0.8.0                    pypi_0    pypi
# msgpack                   1.0.0                    pypi_0    pypi
# msys2-conda-epoch         20160418                      1
# multidict                 4.7.6                    pypi_0    pypi
# munch                     2.5.0                      py_0
# nbconvert                 5.6.1                    py36_0
# nbformat                  5.0.7                      py_0
# nodejs                    14.12.0                       0    conda-forge
# notebook                  6.0.3                    py36_0
# numpy                     1.19.1           py36h5510c5b_0
# numpy-base                1.19.1           py36ha3acd2a_0
# openjpeg                  2.3.0                h5ec785f_1
# openssl                   1.1.1h               he774522_0    conda-forge
# packaging                 20.4                       py_0
# pandas                    1.0.5            py36h47e9c7a_0
# pandoc                    2.10                          0
# pandocfilters             1.4.2                    py36_1
# parso                     0.7.0                      py_0
# pcre                      8.44                 ha925a31_0
# pickleshare               0.7.5                    py36_0
# pip                       20.1.1                   py36_1
# pivottablejs              0.9.0                    py36_0
# postgresql                11.2                 h3235a2c_0
# proj                      6.2.1                h9f7ef89_0
# prometheus_client         0.8.0                      py_0
# prompt-toolkit            3.0.5                      py_0
# prompt_toolkit            3.0.5                         0
# protobuf                  3.13.0                   pypi_0    pypi
# py-spy                    0.3.3                    pypi_0    pypi
# py7zr                     0.9.7                    pypi_0    pypi
# pyarrow                   0.16.0                   pypi_0    pypi
# pycparser                 2.20                       py_2
# pycryptodome              3.9.8                    pypi_0    pypi
# pygments                  2.6.1                      py_0
# pylint                    2.6.0                    pypi_0    pypi
# pyopenssl                 19.1.0                     py_1
# pyparsing                 2.4.7                      py_0
# pyproj                    2.6.1.post1      py36hcfa1391_1
# pyqt                      5.9.2            py36h6538335_2
# pyrsistent                0.16.0           py36he774522_0
# pysocks                   1.7.1                    py36_0
# python                    3.6.10               h9f7ef89_2
# python-dateutil           2.8.1                      py_0
# python_abi                3.6                     1_cp36m    conda-forge
# pytz                      2020.1                     py_0
# pywin32                   227              py36he774522_1
# pywinpty                  0.5.7                    py36_0
# pyyaml                    5.3.1            py36h68a101e_0    conda-forge
# pyzmq                     19.0.1           py36ha925a31_1
# qt                        5.9.7            vc14h73c81de_0
# qtconsole                 4.7.5                      py_0
# qtpy                      1.9.0                      py_0
# ray                       0.8.6                    pypi_0    pypi
# redis                     3.4.1                    pypi_0    pypi
# requests                  2.24.0                     py_0
# rtree                     0.9.4            py36h21ff451_1
# scipy                     1.5.0            py36h9439919_0
# seaborn                   0.10.1                     py_0
# send2trash                1.5.0                    py36_0
# setuptools                49.2.0                   py36_0
# shapely                   1.7.0            py36h210f175_0
# sip                       4.19.8           py36h6538335_0
# six                       1.15.0                     py_0
# soupsieve                 2.0.1                    pypi_0    pypi
# sqlite                    3.32.3               h2a8f88b_0
# tbb                       2018.0.5             he980bc4_0
# terminado                 0.8.3                    py36_0
# testpath                  0.4.4                      py_0
# texttable                 1.6.3                    pypi_0    pypi
# tiledb                    1.6.3                h7b000aa_0
# tk                        8.6.10               he774522_0
# tornado                   5.1.1           py36hfa6e2cd_1000    conda-forge
# traitlets                 4.3.3                    py36_0
# typed-ast                 1.4.1                    pypi_0    pypi
# typing-extensions         3.7.4.3                  pypi_0    pypi
# urllib3                   1.25.9                     py_0
# vc                        14.1                 h0510ff6_4
# vs2015_runtime            14.16.27012          hf0eaf9b_3
# wcwidth                   0.2.5                      py_0
# webencodings              0.5.1                    py36_1
# wget                      3.2                      pypi_0    pypi
# wheel                     0.34.2                   py36_0
# widgetsnbextension        3.5.1                    py36_0
# win_inet_pton             1.1.0                    py36_0
# wincertstore              0.2              py36h7fe50ca_0
# winpty                    0.4.3                         4
# wrapt                     1.12.1                   pypi_0    pypi
# xerces-c                  3.2.2                ha925a31_0
# xz                        5.2.5                h62dcd97_0
# yaml                      0.2.5                he774522_0    conda-forge
# yarl                      1.5.1                    pypi_0    pypi
# zeromq                    4.3.2                ha925a31_2
# zipp                      3.1.0                      py_0
# zlib                      1.2.11               h62dcd97_4
# zstd                      1.3.7                h508b16e_0

# %%
import os
import glob
import pandas as pd
pd.options.display.float_format = '{:,.2f}'.format

# Below some Python modules and functions created for this project are imported
import app_rais.treat as treat
from app_rais.collect import download_rais
from app_rais.collect import extract_rais_original
pd.options.display.max_columns = 50
import app_rais.dicts_constants as dc

# %% [markdown]
# ## COLLECTING RAIS DATA

# %% [markdown]
# In the next cells, **download_rais** function from **collect** module was called for 14 designated Brazilian federation unities (FUs), namely AM, BA, CE, DF, ES, GO, MG, PA, PE, PR, RJ, RS, SC and SP. As a result, the compressed files from **[RAIS Microdata Server](http://pdet.mte.gov.br/microdados-rais-e-caged)** were donwloaded into rais_original subdirectories. Subsequently, the **extract_rais_original** function was applied to these files, decompressing its .txt extension files and deleting the original compressed ones. For 14 FUs, from 1993 to 2018, the original database comprises 399 files, which occupy 374.9GB of disk memory.

# %%
# %%time
download_rais(
    list_ufs=['PR']
    , list_year=list(range(2006,2017))
)
# Out:
# -1 / unknown - D:\innovation_panel\innovation_panel\app_rais\data/rais_original/2006/PR2006.7z downloaded.
# -1 / unknown - D:\innovation_panel\innovation_panel\app_rais\data/rais_original/2007/PR2007.7z downloaded.
# -1 / unknown - D:\innovation_panel\innovation_panel\app_rais\data/rais_original/2008/PR2008.7z downloaded.
# -1 / unknown - D:\innovation_panel\innovation_panel\app_rais\data/rais_original/2009/PR2009.7z downloaded.
# -1 / unknown - D:\innovation_panel\innovation_panel\app_rais\data/rais_original/2010/PR2010.7z downloaded.
# -1 / unknown - D:\innovation_panel\innovation_panel\app_rais\data/rais_original/2011/PR2011.7z downloaded.
# -1 / unknown - D:\innovation_panel\innovation_panel\app_rais\data/rais_original/2012/PR2012.7z downloaded.
# -1 / unknown - D:\innovation_panel\innovation_panel\app_rais\data/rais_original/2013/PR2013.7z downloaded.
# -1 / unknown - D:\innovation_panel\innovation_panel\app_rais\data/rais_original/2014/PR2014.7z downloaded.
# -1 / unknown - D:\innovation_panel\innovation_panel\app_rais\data/rais_original/2015/PR2015.7z downloaded.
# -1 / unknown - D:\innovation_panel\innovation_panel\app_rais\data/rais_original/2016/PR2016.7z downloaded.
# Wall time: 7min 15s

# %%
# %%time
extract_rais_original(
    path_pattern='D:/innovation_panel/innovation_panel/app_rais/data/rais_original/**/**.7z'
    , remove_7z=True
)
# Out:
# "D:/innovation_panel/innovation_panel/app_rais/data/rais_original\2006\PR2006.txt" extracted.
# "D:/innovation_panel/innovation_panel/app_rais/data/rais_original\2007\PR2007.txt" extracted.
# "D:/innovation_panel/innovation_panel/app_rais/data/rais_original\2008\PR2008.txt" extracted.
# "D:/innovation_panel/innovation_panel/app_rais/data/rais_original\2009\PR2009.txt" extracted.
# "D:/innovation_panel/innovation_panel/app_rais/data/rais_original\2010\PR2010.txt" extracted.
# "D:/innovation_panel/innovation_panel/app_rais/data/rais_original\2011\PR2011.txt" extracted.
# "D:/innovation_panel/innovation_panel/app_rais/data/rais_original\2012\PR2012.txt" extracted.
# "D:/innovation_panel/innovation_panel/app_rais/data/rais_original\2013\PR2013.txt" extracted.
# "D:/innovation_panel/innovation_panel/app_rais/data/rais_original\2014\PR2014.txt" extracted.
# "D:/innovation_panel/innovation_panel/app_rais/data/rais_original\2015\PR2015.txt" extracted.
# "D:/innovation_panel/innovation_panel/app_rais/data/rais_original\2016\PR2016.txt" extracted.
# Wall time: 8min 29s

# %%
df_txt = pd.read_table('app_rais/data/rais_original/2006/PR2006.txt', sep=';', encoding='Latin-1', decimal=',');
df_txt.head()
# Out:
# C:\Users\augus\Anaconda3\envs\inovation_panel\lib\site-packages\IPython\core\interactiveshell.py:3263: DtypeWarning: Columns (7,12,14,15,16,22,24,29,35) have mixed types.Specify dtype option on import or set low_memory=False.
#   if (await self.run_code(code, result,  async_=asy)):
#    Bairros SP  Bairros Fortaleza  Bairros RJ Causa Afastamento 1  \
# 0           0                  0           0                  {ñ
# 1           0                  0           0                  {ñ
# 2           0                  0           0                  {ñ
# 3           0                  0           0                  {ñ
# 4           0                  0           0                  40
#
#   Causa Afastamento 2 Causa Afastamento 3  Motivo Desligamento  \
# 0                  {ñ                  {ñ                   11
# 1                  {ñ                  {ñ                   11
# 2                  {ñ                  {ñ                   11
# 3                  {ñ                  {ñ                   11
# 4                  {ñ                  {ñ                   11
#
#   CBO Ocupação 2002  CNAE 2.0 Classe  CNAE 95 Classe  Distritos SP  \
# 0            724315            74901           74993             0
# 1            761205            13111           17213             0
# 2            514210            81214           74705             0
# 3            784205            16218           20214             0
# 4            514210            33198           28991             0
#
#    Vínculo Ativo 31/12 Faixa Etária  Faixa Hora Contrat  \
# 0                    0            3                   6
# 1                    0            5                   6
# 2                    0            7                   6
# 3                    0            7                   6
# 4                    0            7                   6
#
#   Faixa Remun Dezem (SM) Faixa Remun Média (SM) Faixa Tempo Emprego  \
# 0                      0                     03                  06
# 1                      0                     03                  03
# 2                      0                     02                  07
# 3                      0                     02                  03
# 4                      0                     02                  06
#
#    Escolaridade após 2005  Qtd Hora Contr  Idade  Ind CEI Vinculado  \
# 0                       1              44     22                  0
# 1                       1              44     30                  0
# 2                       1              44     58                  0
# 3                       1              44     52                  0
# 4                       1              44     58                  0
#
#    Ind Simples Mês Admissão  Mês Desligamento Mun Trab  Município  \
# 0            1           05                 9   0000-1     410690
# 1            0           07                 2   0000-1     412770
# 2            0           06                 5   411990     411990
# 3            0           10                 6   411990     411990
# 4            1           10                 2   410860     410860
#
#    Nacionalidade  Natureza Jurídica  Qtd Dias Afastamento Raça Cor  \
# 0             10               2062                     0       02
# 1             10               2062                     0       02
# 2             10               2062                     0       02
# 3             10               2062                     0       09
# 4             10               2062                    10       02
#
#   Regiões Adm DF  Vl Remun Dezembro Nom  Vl Remun Dezembro (SM)  \
# 0           {ñ c                   0.00                    0.00
# 1           {ñ c                   0.00                    0.00
# 2           {ñ c                   0.00                    0.00
# 3           {ñ c                   0.00                    0.00
# 4           {ñ c                   0.00                    0.00
#
#    Vl Remun Média Nom  Vl Remun Média (SM) CNAE 2.0 Subclasse  \
# 0              562.54                 1.68            7490101
# 1              545.87                 1.81            1311100
# 2              425.13                 1.33            8121400
# 3              458.25                 1.42            1621800
# 4              366.38                 1.21            3319800
#
#    Sexo Trabalhador  Tamanho Estabelecimento  Tempo Emprego  Tipo Admissão  \
# 0                 1                        2          40.90              0
# 1                 1                        8           7.00              0
# 2                 1                        8          95.00              0
# 3                 1                        2           8.10              0
# 4                 1                        3          52.30              0
#
#    Tipo Estab          Tipo Estab.1  Tipo Vínculo
# 0           1  CNPJ                            10
# 1           1  CNPJ                            10
# 2           1  CNPJ                            10
# 3           1  CNPJ                            10
# 4           1  CNPJ                            10

# %%
df_txt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3307909 entries, 0 to 3307908
# Data columns (total 43 columns):
#  #   Column                   Dtype
# ---  ------                   -----
#  0   Bairros SP               int64
#  1   Bairros Fortaleza        int64
#  2   Bairros RJ               int64
#  3   Causa Afastamento 1      object
#  4   Causa Afastamento 2      object
#  5   Causa Afastamento 3      object
#  6   Motivo Desligamento      int64
#  7   CBO Ocupação 2002        object
#  8   CNAE 2.0 Classe          int64
#  9   CNAE 95 Classe           int64
#  10  Distritos SP             int64
#  11  Vínculo Ativo 31/12      int64
#  12  Faixa Etária             object
#  13  Faixa Hora Contrat       int64
#  14  Faixa Remun Dezem (SM)   object
#  15  Faixa Remun Média (SM)   object
#  16  Faixa Tempo Emprego      object
#  17  Escolaridade após 2005   int64
#  18  Qtd Hora Contr           int64
#  19  Idade                    int64
#  20  Ind CEI Vinculado        int64
#  21  Ind Simples              int64
#  22  Mês Admissão             object
#  23  Mês Desligamento         int64
#  24  Mun Trab                 object
#  25  Município                int64
#  26  Nacionalidade            int64
#  27  Natureza Jurídica        int64
#  28  Qtd Dias Afastamento     int64
#  29  Raça Cor                 object
#  30  Regiões Adm DF           object
#  31  Vl Remun Dezembro Nom    float64
#  32  Vl Remun Dezembro (SM)   float64
#  33  Vl Remun Média Nom       float64
#  34  Vl Remun Média (SM)      float64
#  35  CNAE 2.0 Subclasse       object
#  36  Sexo Trabalhador         int64
#  37  Tamanho Estabelecimento  int64
#  38  Tempo Emprego            float64
#  39  Tipo Admissão            int64
#  40  Tipo Estab               int64
#  41  Tipo Estab.1             object
#  42  Tipo Vínculo             int64
# dtypes: float64(5), int64(24), object(14)
# memory usage: 1.1+ GB

# %%
list_files = glob.glob(f'app_rais/data/rais_original/**/**.txt')
size = round(sum(os.path.getsize(file) for file in list_files) * 1e-9, 2)
print(f'Resulting treated files occupy {size}GB in disk.')
# Out:
# Resulting treated files occupy 16.84GB in disk.

# %% [markdown]
# ## TREATING DATA - FIRST ROUND

# %% [markdown]
# Ahead **original_to_treated_loop** function from **treat** module was called for designated Brazilian federation unities (FU - UF in Portuguese). This function:
# 1. loads original Rais data from .txt extension files inside rais_original subdirectories;
# 2. removes the employment registers not active in 12/31 of each year;
# 3. casts dtypes to its columns for better performance;
# 4. drops columns not relevant for analysis of S&T structure;
# 5. adds data related to S&T personnel, services according to knowledge intensity and industries technological level;
# 6. for each FU and year, saves a compressed pickle file in rais_treated subdirectories.
#
# For 14 selected FUs, from 2007 to 2017, saved files sum up to 7GB on disk.

# %%
# %%time
treat.pretreat_2018(list_ufs=['AM', 'BA', 'CE', 'DF', 'ES', 'GO', 'MG','PA','PE','PR','RJ','RS','SC','SP'])

# %%
df = treat.pretreat_rais(uf='PR', year=2007, treating=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-7a7f0bbbc2c3> in <module>
# ----> 1 df = treat.pretreat_rais(uf='PR', year=2007, treating=True)
#
# D:\innovation_panel\innovation_panel\app_rais\treat.py in pretreat_rais(uf, year, treating)
#     117                 , how='left')
#     118
# --> 119             df['Município'] = df.loc[:, 'Município'].map(get_dict_mun()).astype('category')
#     120
#     121             if (year < 2006) and (year >=1995):
#
# NameError: name 'get_dict_mun' is not defined

# %%
# %%time
treat.original_to_treated_loop(
    ufs=['PR']
    , years=list(range(2007,2018))
)
# Out:
# PR2007.zip saved.
# PR2008.zip saved.

# %%
pd_pickle_ce2008 = pd.read_pickle('app_rais/data/rais_treated/2008/CE2008.zip')

# %%
pd_pickle_ce2008
# Out:
#         CBO Ocupação 2002 CNAE 2.0 Classe CNAE 95 Classe Faixa Etária  \
# 0                  784205           11216          15946           07
# 1                  517420           45111          50105           08
# 2                  622405           01229          01228           07
# 3                  622405           01229          01228           05
# 4                  622405           01229          01228           06
# ...                   ...             ...            ...          ...
# 1129994            514320           82997          74993           05
# 1129995            223115           87301          85316           06
# 1129996            223110           87301          85316           05
# 1129997            234520           85139          80152           05
# 1129998            234520           85139          80152           05
#
#         Faixa Remun Dezem (SM) Faixa Remun Média (SM) Escolaridade após 2005  \
# 0                           03                     02                      1
# 1                          NaN                    NaN                      1
# 2                           02                     02                      1
# 3                           03                     02                      1
# 4                           02                     01                      1
# ...                        ...                    ...                    ...
# 1129994                     03                     02                     11
# 1129995                     09                     08                     11
# 1129996                     10                     09                     11
# 1129997                     11                     10                     11
# 1129998                     11                     10                     11
#
#          Idade Ind Simples Município Nacionalidade Natureza Jurídica Raça Cor  \
# 0           61           0    230440            10              2062       08
# 1           69           0    230440            10              2062       09
# 2           53           0    231020            10              2062       08
# 3           31           0    231020            10              2062       04
# 4           42           0    231020            10              2062       08
# ...        ...         ...       ...           ...               ...      ...
# 1129994     31           0    230370            10              2062       08
# 1129995     49           0    230440            10              3999       08
# 1129996     38           0    230440            10              3999       08
# 1129997     37           0    230440            10              2062       02
# 1129998     36           0    230440            10              2062       02
#
#          Vl Remun Dezembro Nom  Vl Remun Dezembro (SM)  Vl Remun Média Nom  \
# 0                       550.83                    1.32              500.64
# 1                         0.00                    0.00                0.00
# 2                       394.92                    0.95              416.97
# 3                       574.84                    1.38              418.60
# 4                       348.06                    0.83              393.39
# ...                        ...                     ...                 ...
# 1129994                 437.71                    1.05              437.71
# 1129995               3,200.00                    7.71            3,287.27
# 1129996               4,500.00                   10.84            4,500.00
# 1129997               7,221.26                   17.40            7,118.89
# 1129998               7,623.33                   18.36            7,656.21
#
#          Vl Remun Média (SM)      Sexo Trabalhador Tamanho Estabelecimento  \
# 0                       1.21                    01                       8
# 1                       0.00                    01                       6
# 2                       1.01                    01                       6
# 3                       1.02                    01                       6
# 4                       0.95                    01                       6
# ...                      ...                   ...                     ...
# 1129994                 1.05                    02                      10
# 1129995                 7.91                    02                       6
# 1129996                10.84                    02                       6
# 1129997                17.36                    02                       7
# 1129998                18.68                    02                       7
#
#         Tipo Estab          Tipo Estab.1 territorio_tese  \
# 0               01  CNPJ                             NaN
# 1               01  CNPJ                             NaN
# 2               01  CNPJ                             NaN
# 3               01  CNPJ                             NaN
# 4               01  CNPJ                             NaN
# ...            ...                   ...             ...
# 1129994         01  CNPJ                             NaN
# 1129995         01  CNPJ                             NaN
# 1129996         01  CNPJ                             NaN
# 1129997         01  CNPJ                             NaN
# 1129998         01  CNPJ                             NaN
#
#                                       arranjo  \
# 0        Arranjo Populacional de Fortaleza/CE
# 1        Arranjo Populacional de Fortaleza/CE
# 2                  Demais Municípios do Ceará
# 3                  Demais Municípios do Ceará
# 4                  Demais Municípios do Ceará
# ...                                       ...
# 1129994  Arranjo Populacional de Fortaleza/CE
# 1129995  Arranjo Populacional de Fortaleza/CE
# 1129996  Arranjo Populacional de Fortaleza/CE
# 1129997  Arranjo Populacional de Fortaleza/CE
# 1129998  Arranjo Populacional de Fortaleza/CE
#
#                                knowledge_services   technology_industries  \
# 0                          Without Classification          Low-technology
# 1        Less knowledge-intensive market services  Without Classification
# 2                          Without Classification  Without Classification
# 3                          Without Classification  Without Classification
# 4                          Without Classification  Without Classification
# ...                                           ...                     ...
# 1129994  Less knowledge-intensive market services  Without Classification
# 1129995        Other knowledge-intensive services  Without Classification
# 1129996        Other knowledge-intensive services  Without Classification
# 1129997        Other knowledge-intensive services  Without Classification
# 1129998        Other knowledge-intensive services  Without Classification
#
#                                   potec
# 0                      Demais Ocupações
# 1                      Demais Ocupações
# 2                      Demais Ocupações
# 3                      Demais Ocupações
# 4                      Demais Ocupações
# ...                                 ...
# 1129994                Demais Ocupações
# 1129995                Demais Ocupações
# 1129996                Demais Ocupações
# 1129997  Professores de ensino superior
# 1129998  Professores de ensino superior
#
# [1129999 rows x 26 columns]

# %%
list_files = glob.glob(f'app_rais/data/rais_treated/**/**.zip')
size = round(sum(os.path.getsize(file) for file in list_files) * 1e-9, 2)
print(f'Resulting treated files occupy {size}GB in disk.')
# Out:
# Resulting treated files occupy 7.03GB in disk.

# %% [markdown]
# ## TREATING DATA - SECOND ROUND

# %% [markdown]
# The pickle files generated by the first round of data treatment are used ahead as input for Generate_rais_dataframe, which applies a new round of treatment, grouping data for better use of memory, merging information from different UFs and creating columns for personnel data, namely:
#
# * scientific and technical (S&T) personnel (POTEC);
# * organization legal status;
# * economic sectors;
# * categories of services according to intensity of applied knowledge;
# * industry technological levels;
# * level of education.
#
# This function is called by another function, load_save_rais_dataframe_loop, which applies it to different years and saves the result as feather files, optimized for fast usage. When applied to selected Federation Unities, from 2007 to 2017, resulting data base encompassed 11 files that sum 0.14GB of disk memory.

# %%
# %%time
df_2007 = treat.generate_rais_dataframe(list_ufs=['PR'], year=2007)
# Out:
# Wall time: 34.5 s

# %%
df_2007
# Out:
#         UF Município   Sectors Tamanho Estabelecimento  \
# 0       PR    410010  Services                  Até 49
# 1       PR    410010  Services                  Até 49
# 2       PR    410010  Services                  Até 49
# 3       PR    410010  Services                  Até 49
# 4       PR    410010  Services                  Até 49
# ...     ..       ...       ...                     ...
# 104081  PR    412880  Services            de 100 a 249
# 104082  PR    412880  Services            de 100 a 249
# 104083  PR    412880  Services            de 100 a 249
# 104084  PR    412880  Services            de 100 a 249
# 104085  PR    412880  Services            de 100 a 249
#
#        Natureza Jurídica Grupo Natureza Jurídica  \
# 0       Entidades Empresariais       SOC QT LTDA
# 1       Entidades Empresariais       SOC QT LTDA
# 2       Entidades Empresariais       SOC QT LTDA
# 3       Entidades Empresariais       SOC QT LTDA
# 4       Entidades Empresariais       SOC QT LTDA
# ...                        ...               ...
# 104081   Administração Pública       POD EXEC MU
# 104082   Administração Pública       POD EXEC MU
# 104083   Administração Pública       POD EXEC MU
# 104084   Administração Pública       POD EXEC MU
# 104085   Administração Pública       POD EXEC MU
#
#                               knowledge_services   technology_industries  \
# 0       Less knowledge-intensive market services  Without Classification
# 1       Less knowledge-intensive market services  Without Classification
# 2       Less knowledge-intensive market services  Without Classification
# 3       Less knowledge-intensive market services  Without Classification
# 4       Less knowledge-intensive market services  Without Classification
# ...                                          ...                     ...
# 104081        Other knowledge-intensive services  Without Classification
# 104082        Other knowledge-intensive services  Without Classification
# 104083        Other knowledge-intensive services  Without Classification
# 104084        Other knowledge-intensive services  Without Classification
# 104085        Other knowledge-intensive services  Without Classification
#
#              Potec Grupo             potec Escolaridade1  \
# 0       Demais Ocupações  Demais Ocupações  Não-Superior
# 1       Demais Ocupações  Demais Ocupações  Não-Superior
# 2       Demais Ocupações  Demais Ocupações  Não-Superior
# 3       Demais Ocupações  Demais Ocupações  Não-Superior
# 4       Demais Ocupações  Demais Ocupações  Não-Superior
# ...                  ...               ...           ...
# 104081  Demais Ocupações  Demais Ocupações  Não-Superior
# 104082  Demais Ocupações  Demais Ocupações  Não-Superior
# 104083  Demais Ocupações  Demais Ocupações  Não-Superior
# 104084  Demais Ocupações  Demais Ocupações  Não-Superior
# 104085  Demais Ocupações  Demais Ocupações      Superior
#
#                               Escolaridade2  Pessoal
# 0         Inferior ao Ensino Médio Completo        2
# 1         Inferior ao Ensino Médio Completo        1
# 2         Inferior ao Ensino Médio Completo        5
# 3         Inferior ao Ensino Médio Completo        3
# 4       Ensino Médio ao Superior Incompleto       19
# ...                                     ...      ...
# 104081    Inferior ao Ensino Médio Completo       12
# 104082    Inferior ao Ensino Médio Completo        6
# 104083  Ensino Médio ao Superior Incompleto       56
# 104084  Ensino Médio ao Superior Incompleto        3
# 104085                             Superior       58
#
# [104086 rows x 13 columns]

# %%
df_2007.head()
# Out:
#        UF                           Território   Sectors  \
# 0      PR          Demais Municípios do Paraná  Services
# 1      PR          Demais Municípios do Paraná  Services
# 2      PR          Demais Municípios do Paraná  Services
# 3      PR          Demais Municípios do Paraná  Services
# 4      PR          Demais Municípios do Paraná  Services
# ...    ..                                  ...       ...
# 13700  PR  Arranjo Populacional de Curitiba/PR  Services
# 13701  PR  Arranjo Populacional de Curitiba/PR  Services
# 13702  PR  Arranjo Populacional de Curitiba/PR  Services
# 13703  PR  Arranjo Populacional de Curitiba/PR  Services
# 13704  PR  Arranjo Populacional de Curitiba/PR  Services
#
#       Tamanho Estabelecimento Natureza Jurídica Grupo Natureza Jurídica  \
# 0                      Até 49  Entidades Empresariais       SOC QT LTDA
# 1                      Até 49  Entidades Empresariais       SOC QT LTDA
# 2                      Até 49  Entidades Empresariais       SOC QT LTDA
# 3                      Até 49  Entidades Empresariais       SOC QT LTDA
# 4                      Até 49  Entidades Empresariais       SOC QT LTDA
# ...                       ...                     ...               ...
# 13700        a partir de 1000   Administração Pública       POD JUD FED
# 13701        a partir de 1000   Administração Pública       POD JUD FED
# 13702        a partir de 1000   Administração Pública       POD JUD FED
# 13703        a partir de 1000   Administração Pública       POD JUD FED
# 13704        a partir de 1000   Administração Pública       POD JUD FED
#
#                            knowledge_services   technology_industries  \
# 0      High-tech knowledge-intensive services  Without Classification
# 1      High-tech knowledge-intensive services  Without Classification
# 2      High-tech knowledge-intensive services  Without Classification
# 3      High-tech knowledge-intensive services  Without Classification
# 4      High-tech knowledge-intensive services  Without Classification
# ...                                       ...                     ...
# 13700      Other knowledge-intensive services  Without Classification
# 13701      Other knowledge-intensive services  Without Classification
# 13702      Other knowledge-intensive services  Without Classification
# 13703      Other knowledge-intensive services  Without Classification
# 13704      Other knowledge-intensive services  Without Classification
#
#                      Potec Grupo                         potec Escolaridade1  \
# 0               Demais Ocupações              Demais Ocupações  Não-Superior
# 1               Demais Ocupações              Demais Ocupações  Não-Superior
# 2      Profissionais científicos  Profissionais da Informática  Não-Superior
# 3               Demais Ocupações              Demais Ocupações  Não-Superior
# 4               Demais Ocupações              Demais Ocupações  Não-Superior
# ...                          ...                           ...           ...
# 13700  Profissionais científicos  Profissionais da Informática      Superior
# 13701           Demais Ocupações              Demais Ocupações      Superior
# 13702  Profissionais científicos  Profissionais da Informática      Mestrado
# 13703           Demais Ocupações              Demais Ocupações      Mestrado
# 13704           Demais Ocupações              Demais Ocupações     Doutorado
#
#                            Escolaridade2  Pessoal
# 0      Inferior ao Ensino Médio Completo        1
# 1      Inferior ao Ensino Médio Completo        7
# 2      Inferior ao Ensino Médio Completo        1
# 3      Inferior ao Ensino Médio Completo       10
# 4      Inferior ao Ensino Médio Completo       33
# ...                                  ...      ...
# 13700                           Superior       11
# 13701                           Superior     2785
# 13702                           Mestrado        4
# 13703                           Mestrado       46
# 13704                          Doutorado        1
#
# [13705 rows x 13 columns]

# %%
# %%time
treat.load_save_rais_dataframe_loop(
    list_ufs=['AM', 'BA', 'CE', 'DF', 'ES', 'GO', 'MG','PA','PE','PR','RJ','RS','SC','SP']
    , list_years=list(range(2007,2019)
          )
)
# Out:
# ufs_with_motropolises_2007 saved.
# ufs_with_motropolises_2008 saved.
# ufs_with_motropolises_2009 saved.
# ufs_with_motropolises_2010 saved.
# ufs_with_motropolises_2011 saved.
# ufs_with_motropolises_2012 saved.
# ufs_with_motropolises_2013 saved.
# ufs_with_motropolises_2014 saved.
# ufs_with_motropolises_2015 saved.
# ufs_with_motropolises_2016 saved.
# ufs_with_motropolises_2017 saved.
# Wall time: 20min 5s

# %%
list_files = glob.glob(f'app_rais/data/rais_dataframes/**.ftd')
size = round(sum(os.path.getsize(file) for file in list_files) * 1e-9, 2)
print(f'Resulting treated files occupy {size}GB in disk.')
# Out:
# Resulting treated files occupy 0.14GB in disk.
